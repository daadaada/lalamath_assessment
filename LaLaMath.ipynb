# %%
# %matplotlib inline
import numpy as np

import scipy.stats as st
import matplotlib.pyplot as plt
from scipy import stats
import math
import datetime

# %%
mean1 = [0 for _ in range(101)]

cov1 = np.diag([1 for _ in range(101)])

# Knowledge
theta1 = stats.multivariate_normal(mean=mean1, cov=cov1)

mean2 = [0 for _ in range(4)]

cov2 = np.diag([0.8 for _ in range(4)])

# Skill
theta2 = stats.multivariate_normal(mean=mean2, cov=cov2)

# Take samples
data1 = theta1.rvs()
data2 = theta2.rvs()
print(type(data2))
# Out:
# <class 'numpy.ndarray'>

# %%
theta = np.array([1, 2, 3])
mean = np.array([0.5, 0.5, 0.5])
cov = np.diag([1, 1, 1])
print(np.matmul(cov, (theta - mean)))
# Out:
# [ 0.5  1.5  2.5]

# %%
def pseudo_posterior(theta, mean, cov, knowledge_weight, skill_weight, 
                     answer, difficulty, guessing_para, N=101):
    '''
    theta: 
        
    '''
    p = guessing_para + (1 - guessing_para) * \
        sigmoid(np.matmul(np.transpose(theta[0:N]), knowledge_weight) - difficulty) * \
        sigmoid(np.matmul(np.transpose(theta[N:]), skill_weight) - difficulty)
    
    # Calculate likelihood
    likelihood = p**answer * (1-p)**(1-answer)
    
    pseudo_posterior = likelihood * \
    math.exp(-0.5*np.matmul(np.matmul(np.transpose(theta - mean), np.linalg.inv(cov)), (theta - mean)))
    
    return pseudo_posterior

def sigmoid(x):
    return 1 / (1 + math.exp(-x))

def time_to_day(time_delta):
    days = time_delta.day + time_delta.hour / 24 + time_delta.minute / 1440 + time_delta.second / 86400
    return days
    
def gibbs_sampling(mean, cov, knowledge_weight, skill_weight, 
                     answer, difficulty, guessing_para, N=101):
    '''
    return:
        mean, cov of approximation with gibbs sampling
    '''
    prior_dist = stats.multivariate_normal(mean=mean, cov=cov)
    current_theta = prior_dist.rvs()
    # Calculate w_l
    Gibbs_samples = []
    for iter in range(600):
        time1 = datetime.datetime.now()
        for i in range(105):
            z = prior_dist.rvs(size=100)
            for item in z:
                for index in range(len(item)):
                    if index == i:
                        continue
                    item[index] = current_theta[index]
            numerator = []
            for item in z:
                p = pseudo_posterior(item, mean, cov, knowledge_weight, skill_weight, 
                     answer, difficulty, guessing_para)
                q = prior_dist.pdf(item)
                numerator.append(p/q)
            denominator = sum(numerator)
            w_l = [x/denominator for x in numerator]
            chosen_z_idx = np.random.choice(100, 1, p=w_l)
            chosen_z = z[chosen_z_idx]
            current_theta[i] = chosen_z[0][i]
        Gibbs_samples.append(current_theta)
        time2 = datetime.datetime.now()
        print('Iteration {}. Time: {}\n'.format(iter, time2 - time1))
    
    Gibbs_samples = Gibbs_samples[100:]
    Gibbs_samples = np.array(Gibbs_samples)
    mean = np.mean(Gibbs_samples, axis=0)
    cov = np.cov(Gibbs_samples, rowvar=False)
    
    return mean, cov
    
                 
    

# Update distribution
def update_theta(mean, cov, question_no, answer, last_time,
                 knowledge_weight, skill_weight, difficulty, guessing_para, N=101):
    '''
    Input:
    answer: binary, 0 - wrong, 1 - correct
    knowledge_weight: 101*1 vector
    skill_weight: 4*1 vector
    difficulty: string
    
    return:
    new_mean
    new_cov
    update_time
    '''
    # Get time delta
    # t2 - t1 (in days)
    now = datetime.datetime.now()
    days = time_to_day(now - last_time)
                 
    # Step0: Brownian motion
    mean = mean + 0.008 * days
    cov = np.add(cov, np.diag([0.008*days for _ in range(105)]))
    
    # Step1: Get prior sample
    norm_dist = stats.multivariate_normal(mean=mean, cov=cov)
    prior_sample = norm_dist.rvs()
    prior_sample_knowledge = prior_sample[0:N]
    prior_sample_skill = prior_sample[N:]
    
    # Step2: Generating samples from posterior
    gibbs_mean, gibbs_cov = gibbs_sampling(mean, cov, knowledge_weight, skill_weight, 
                     answer, difficulty, guessing_para)

# %%
knowledge_weight = [np.random.choice([0,1]) for _ in range(101)]

# %%
skill_weight = [np.random.choice([0,1]) for _ in range(4)]

# %%
time1 = datetime.datetime.now()
mean, cov = gibbs_sampling([0 for _ in range(105)], np.diag([1 for _ in range(101)] + [0.8 for _ in range(4)]),
                          knowledge_weight, skill_weight,1, 2, 0.25)
time2 = datetime.datetime.now()
print(time2-time1)
# Out:
# Iteration 0. Time: 0:00:08.294427
#
# Iteration 1. Time: 0:00:08.932065
#
# Iteration 2. Time: 0:00:07.679656
#
# Iteration 3. Time: 0:00:08.299462
#
# Iteration 4. Time: 0:00:09.161990
#
# Iteration 5. Time: 0:00:08.679282
#
# Iteration 6. Time: 0:00:10.209145
#
# Iteration 7. Time: 0:00:08.292400
#
# Iteration 8. Time: 0:00:08.113947
#
# Iteration 9. Time: 0:00:09.050769
#
# Iteration 10. Time: 0:00:08.981661
#
# Iteration 11. Time: 0:00:07.869338
#
# Iteration 12. Time: 0:00:07.992737
#
# Iteration 13. Time: 0:00:07.706870
#
# Iteration 14. Time: 0:00:07.998259
#
# Iteration 15. Time: 0:00:08.177054
#
# Iteration 16. Time: 0:00:08.376938
#
# Iteration 17. Time: 0:00:08.315301
#
# Iteration 18. Time: 0:00:07.968607
#
# Iteration 19. Time: 0:00:07.884188
#
# Iteration 20. Time: 0:00:08.334739
#
# Iteration 21. Time: 0:00:07.545504
#
# Iteration 22. Time: 0:00:08.759003
#
# Iteration 23. Time: 0:00:08.056518
#
# Iteration 24. Time: 0:00:08.465745
#
# Iteration 25. Time: 0:00:09.010600
#
# Iteration 26. Time: 0:00:07.188879
#
# Iteration 27. Time: 0:00:07.822995
#
# Iteration 28. Time: 0:00:08.205132
#
# Iteration 29. Time: 0:00:08.192278
#
# Iteration 30. Time: 0:00:08.696571
#
# Iteration 31. Time: 0:00:08.733833
#
# Iteration 32. Time: 0:00:08.325876
#
# Iteration 33. Time: 0:00:08.200975
#
# Iteration 34. Time: 0:00:11.034711
#
# Iteration 35. Time: 0:00:08.734262
#
# Iteration 36. Time: 0:00:08.435168
#
# Iteration 37. Time: 0:00:08.018687
#
# Iteration 38. Time: 0:00:12.457302
#
# Iteration 39. Time: 0:00:08.668821
#
# Iteration 40. Time: 0:00:08.841447
#
# Iteration 41. Time: 0:00:09.220795
#
# Iteration 42. Time: 0:00:10.475761
#
# Iteration 43. Time: 0:00:10.105899
#
# Iteration 44. Time: 0:00:07.910977
#
# Iteration 45. Time: 0:00:08.707123
#
# Iteration 46. Time: 0:00:08.386423
#
# Iteration 47. Time: 0:00:08.421681
#
# Iteration 48. Time: 0:00:08.656254
#
# Iteration 49. Time: 0:00:08.422943
#
# Iteration 50. Time: 0:00:08.523863
#
# Iteration 51. Time: 0:00:08.200601
#
# Iteration 52. Time: 0:00:08.141036
#
# Iteration 53. Time: 0:00:07.743381
#
# Iteration 54. Time: 0:00:07.954431
#
# Iteration 55. Time: 0:00:08.228715
#
# Iteration 56. Time: 0:00:07.823131
#
# Iteration 57. Time: 0:00:07.963701
#
# Iteration 58. Time: 0:00:07.958041
#
# Iteration 59. Time: 0:00:07.815639
#
# Iteration 60. Time: 0:00:07.679508
#
# Iteration 61. Time: 0:00:05.138918
#
# Iteration 62. Time: 0:00:05.560236
#
# Iteration 63. Time: 0:00:05.155304
#
# Iteration 64. Time: 0:00:06.118510
#
# Iteration 65. Time: 0:00:04.891357
#
# Iteration 66. Time: 0:00:05.151137
#
# Iteration 67. Time: 0:00:05.064121
#
# Iteration 68. Time: 0:00:04.886405
#
# Iteration 69. Time: 0:00:04.869331
#
# Iteration 70. Time: 0:00:05.466949
#
# Iteration 71. Time: 0:00:05.652047
#
# Iteration 72. Time: 0:00:04.830496
#
# Iteration 73. Time: 0:00:04.929230
#
# Iteration 74. Time: 0:00:06.048546
#
# Iteration 75. Time: 0:00:07.506349
#
# Iteration 76. Time: 0:00:05.655632
#
# Iteration 77. Time: 0:00:06.978727
#
# Iteration 78. Time: 0:00:09.453902
#
# Iteration 79. Time: 0:00:06.619307
#
# Iteration 80. Time: 0:00:06.796738
#
# Iteration 81. Time: 0:00:07.447940
#
# Iteration 82. Time: 0:00:06.996085
#
# Iteration 83. Time: 0:00:07.127284
#
# Iteration 84. Time: 0:00:07.550007
#
# Iteration 85. Time: 0:00:09.033051
#
# Iteration 86. Time: 0:00:08.177818
#
# Iteration 87. Time: 0:00:08.046756
#
# Iteration 88. Time: 0:00:07.940857
#
# Iteration 89. Time: 0:00:07.465508
#
# Iteration 90. Time: 0:00:07.367959
#
# Iteration 91. Time: 0:00:07.069566
#
# Iteration 92. Time: 0:00:06.714668
#
# Iteration 93. Time: 0:00:07.637087
#
# Iteration 94. Time: 0:00:07.767851
#
# Iteration 95. Time: 0:00:07.867307
#
# Iteration 96. Time: 0:00:07.490709
#
# Iteration 97. Time: 0:00:07.389738
#
# Iteration 98. Time: 0:00:07.067282
#
# Iteration 99. Time: 0:00:07.422373
#
# Iteration 100. Time: 0:00:07.179503
#
# Iteration 101. Time: 0:00:06.466269
#
# Iteration 102. Time: 0:00:06.751660
#
# Iteration 103. Time: 0:00:07.139119
#
# Iteration 104. Time: 0:00:07.730912
#
# Iteration 105. Time: 0:00:07.320209
#
# Iteration 106. Time: 0:00:06.509468
#
# Iteration 107. Time: 0:00:06.513165
#
# Iteration 108. Time: 0:00:06.874979
#
# Iteration 109. Time: 0:00:07.250719
#
# Iteration 110. Time: 0:00:07.245276
#
# Iteration 111. Time: 0:00:06.799730
#
# Iteration 112. Time: 0:00:07.130204
#
# Iteration 113. Time: 0:00:07.528129
#
# Iteration 114. Time: 0:00:07.746879
#
# Iteration 115. Time: 0:00:07.997014
#
# Iteration 116. Time: 0:00:08.733699
#
# Iteration 117. Time: 0:00:07.402778
#
# Iteration 118. Time: 0:00:07.125668
#
# Iteration 119. Time: 0:00:06.857511
#
# Iteration 120. Time: 0:00:07.509919
#
# Iteration 121. Time: 0:00:08.094477
#
# Iteration 122. Time: 0:00:08.047958
#
# Iteration 123. Time: 0:00:07.595849
#
# Iteration 124. Time: 0:00:07.584407
#
# Iteration 125. Time: 0:00:07.756316
#
# Iteration 126. Time: 0:00:07.296845
#
# Iteration 127. Time: 0:00:07.124821
#
# Iteration 128. Time: 0:00:06.871966
#
# Iteration 129. Time: 0:00:07.534380
#
# Iteration 130. Time: 0:00:07.821020
#
# Iteration 131. Time: 0:00:08.150905
#
# Iteration 132. Time: 0:00:07.813625
#
# Iteration 133. Time: 0:00:07.298907
#
# Iteration 134. Time: 0:00:06.824047
#
# Iteration 135. Time: 0:00:06.108920
#
# Iteration 136. Time: 0:00:06.266768
#
# Iteration 137. Time: 0:00:06.545011
#
# Iteration 138. Time: 0:00:07.060767
#
# Iteration 139. Time: 0:00:07.609417
#
# Iteration 140. Time: 0:00:07.743179
#
# Iteration 141. Time: 0:00:06.839171
#
# Iteration 142. Time: 0:00:06.197122
#
# Iteration 143. Time: 0:00:05.993238
#
# Iteration 144. Time: 0:00:06.081474
#
# Iteration 145. Time: 0:00:06.585039
#
# Iteration 146. Time: 0:00:06.984490
#
# Iteration 147. Time: 0:00:06.846086
#
# Iteration 148. Time: 0:00:06.923610
#
# Iteration 149. Time: 0:00:06.981098
#
# Iteration 150. Time: 0:00:07.345528
#
# Iteration 151. Time: 0:00:07.285591
#
# Iteration 152. Time: 0:00:07.450194
#
# Iteration 153. Time: 0:00:07.468072
#
# Iteration 154. Time: 0:00:11.701684
#
# Iteration 155. Time: 0:00:08.444409
#
# Iteration 156. Time: 0:00:06.480959
#
# Iteration 157. Time: 0:00:06.506599
#
# Iteration 158. Time: 0:00:04.895745
#
# Iteration 159. Time: 0:00:10.311232
#
# Iteration 160. Time: 0:00:10.352212
#
# Iteration 161. Time: 0:00:08.928255
#
# Iteration 162. Time: 0:00:08.804376
#
# Iteration 163. Time: 0:00:08.397417
#
# Iteration 164. Time: 0:00:09.087384
#
# Iteration 165. Time: 0:00:08.672126
#
# Iteration 166. Time: 0:00:08.427948
#
# Iteration 167. Time: 0:00:06.284551
#
# Iteration 168. Time: 0:00:10.878001
#
# Iteration 169. Time: 0:00:09.586825
#
# Iteration 170. Time: 0:00:08.731156
#
# Iteration 171. Time: 0:00:09.146925
#
# Iteration 172. Time: 0:00:10.408861
#
# Iteration 173. Time: 0:00:08.176808
#
# Iteration 174. Time: 0:00:05.567046
#
# Iteration 175. Time: 0:00:07.331838
#
# Iteration 176. Time: 0:00:10.440033
#
# Iteration 177. Time: 0:00:05.831869
#
# Iteration 178. Time: 0:00:09.399929
#
# Iteration 179. Time: 0:00:06.819859
#
# Iteration 180. Time: 0:00:06.214892
#
# Iteration 181. Time: 0:00:06.198355
#
# Iteration 182. Time: 0:00:06.235680
#
# Iteration 183. Time: 0:00:06.262439
#
# Iteration 184. Time: 0:00:06.154492
#
# Iteration 185. Time: 0:00:06.136922
#
# Iteration 186. Time: 0:00:06.227412
#
# Iteration 187. Time: 0:00:06.199030
#
# Iteration 188. Time: 0:00:06.245850
#
# Iteration 189. Time: 0:00:06.255189
#
# Iteration 190. Time: 0:00:08.058662
#
# Iteration 191. Time: 0:00:07.183285
#
# Iteration 192. Time: 0:00:06.375105
#
# Iteration 193. Time: 0:00:06.074742
#
# Iteration 194. Time: 0:00:05.580714
#
# Iteration 195. Time: 0:00:05.717333
#
# Iteration 196. Time: 0:00:05.889278
#
# Iteration 197. Time: 0:00:05.865507
#
# Iteration 198. Time: 0:00:07.326172
#
# Iteration 199. Time: 0:00:05.806817
#
# Iteration 200. Time: 0:00:05.468083
#
# Iteration 201. Time: 0:00:05.505194
#
# Iteration 202. Time: 0:00:05.749651
#
# Iteration 203. Time: 0:00:05.527924
#
# Iteration 204. Time: 0:00:07.056563
#
# Iteration 205. Time: 0:00:05.423817
#
# Iteration 206. Time: 0:00:05.568262
#
# Iteration 207. Time: 0:00:05.334204
#
# Iteration 208. Time: 0:00:06.722128
#
# Iteration 209. Time: 0:00:07.567525
#
# Iteration 210. Time: 0:00:06.654747
#
# Iteration 211. Time: 0:00:05.238672
#
# Iteration 212. Time: 0:00:04.635747
#
# Iteration 213. Time: 0:00:05.137987
#
# Iteration 214. Time: 0:00:05.158579
#
# Iteration 215. Time: 0:00:05.197053
#
# Iteration 216. Time: 0:00:05.422054
#
# Iteration 217. Time: 0:00:05.893048
#
# Iteration 218. Time: 0:00:06.343330
#
# Iteration 219. Time: 0:00:07.197543
#
# Iteration 220. Time: 0:00:04.908322
#
# Iteration 221. Time: 0:00:04.591947
#
# Iteration 222. Time: 0:00:04.511472
#
# Iteration 223. Time: 0:00:04.526578
#
# Iteration 224. Time: 0:00:04.543917
# Iteration 225. Time: 0:00:04.531942
#
# Iteration 226. Time: 0:00:04.512602
#
# Iteration 227. Time: 0:00:04.533697
#
# Iteration 228. Time: 0:00:04.506520
#
# Iteration 229. Time: 0:00:04.538717
#
# Iteration 230. Time: 0:00:04.724753
#
# Iteration 231. Time: 0:00:04.982524
#
# Iteration 232. Time: 0:00:05.240315
#
# Iteration 233. Time: 0:00:04.942848
#
# Iteration 234. Time: 0:00:05.056415
#
# Iteration 235. Time: 0:00:05.143165
#
# Iteration 236. Time: 0:00:04.874807
#
# Iteration 237. Time: 0:00:04.843825
#
# Iteration 238. Time: 0:00:04.899584
#
# Iteration 239. Time: 0:00:04.832660
#
# Iteration 240. Time: 0:00:04.838086
#
# Iteration 241. Time: 0:00:04.877733
#
# Iteration 242. Time: 0:00:04.989270
#
# Iteration 243. Time: 0:00:04.537953
#
# Iteration 244. Time: 0:00:04.494678
#
# Iteration 245. Time: 0:00:04.549050
#
# Iteration 246. Time: 0:00:04.545220
#
# Iteration 247. Time: 0:00:04.533043
#
# Iteration 248. Time: 0:00:04.530476
#
# Iteration 249. Time: 0:00:04.510679
#
# Iteration 250. Time: 0:00:04.495373
#
# Iteration 251. Time: 0:00:04.517317
#
# Iteration 252. Time: 0:00:04.519772
#
# Iteration 253. Time: 0:00:04.503221
#
# Iteration 254. Time: 0:00:04.521280
#
# Iteration 255. Time: 0:00:04.760267
#
# Iteration 256. Time: 0:00:04.477881
#
# Iteration 257. Time: 0:00:04.560342
#
# Iteration 258. Time: 0:00:04.492840
#
# Iteration 259. Time: 0:00:04.501262
#
# Iteration 260. Time: 0:00:04.505266
#
# Iteration 261. Time: 0:00:04.521218
#
# Iteration 262. Time: 0:00:04.524419
#
# Iteration 263. Time: 0:00:04.488809
#
# Iteration 264. Time: 0:00:04.497078
#
# Iteration 265. Time: 0:00:04.484388
#
# Iteration 266. Time: 0:00:04.512359
#
# Iteration 267. Time: 0:00:04.494272
#
# Iteration 268. Time: 0:00:04.626622
#
# Iteration 269. Time: 0:00:04.542073
#
# Iteration 270. Time: 0:00:04.492630
#
# Iteration 271. Time: 0:00:04.519612
#
# Iteration 272. Time: 0:00:04.513196
#
# Iteration 273. Time: 0:00:04.484741
#
# Iteration 274. Time: 0:00:04.508817
#
# Iteration 275. Time: 0:00:04.538174
#
# Iteration 276. Time: 0:00:04.496811
#
# Iteration 277. Time: 0:00:04.474983
#
# Iteration 278. Time: 0:00:04.505394
#
# Iteration 279. Time: 0:00:04.547822
#
# Iteration 280. Time: 0:00:04.500119
#
# Iteration 281. Time: 0:00:04.616360
#
# Iteration 282. Time: 0:00:04.636452
#
# Iteration 283. Time: 0:00:04.495169
#
# Iteration 284. Time: 0:00:04.554483
#
# Iteration 285. Time: 0:00:05.091063
#
# Iteration 286. Time: 0:00:04.507260
#
# Iteration 287. Time: 0:00:04.518392
#
# Iteration 288. Time: 0:00:04.528875
#
# Iteration 289. Time: 0:00:04.474400
#
# Iteration 290. Time: 0:00:04.484681
#
# Iteration 291. Time: 0:00:04.524319
#
# Iteration 292. Time: 0:00:04.500057
#
# Iteration 293. Time: 0:00:04.519661
#
# Iteration 294. Time: 0:00:04.518228
#
# Iteration 295. Time: 0:00:04.656547
#
# Iteration 296. Time: 0:00:04.487846
#
# Iteration 297. Time: 0:00:04.501083
#
# Iteration 298. Time: 0:00:04.537437
#
# Iteration 299. Time: 0:00:04.571843
#
# Iteration 300. Time: 0:00:04.469569
#
# Iteration 301. Time: 0:00:04.492476
#
# Iteration 302. Time: 0:00:04.561888
#
# Iteration 303. Time: 0:00:04.516044
#
# Iteration 304. Time: 0:00:04.519369
#
# Iteration 305. Time: 0:00:04.534556
#
# Iteration 306. Time: 0:00:04.507116
#
# Iteration 307. Time: 0:00:04.520401
#
# Iteration 308. Time: 0:00:04.659212
#
# Iteration 309. Time: 0:00:04.496403
#
# Iteration 310. Time: 0:00:04.506550
#
# Iteration 311. Time: 0:00:04.510289
#
# Iteration 312. Time: 0:00:04.527454
#
# Iteration 313. Time: 0:00:04.480353
#
# Iteration 314. Time: 0:00:04.485700
#
# Iteration 315. Time: 0:00:04.703467
#
# Iteration 316. Time: 0:00:04.540577
#
# Iteration 317. Time: 0:00:04.751613
#
# Iteration 318. Time: 0:00:04.507903
#
# Iteration 319. Time: 0:00:04.515292
#
# Iteration 320. Time: 0:00:04.553852
#
# Iteration 321. Time: 0:00:04.640367
#
# Iteration 322. Time: 0:00:04.510604
#
# Iteration 323. Time: 0:00:04.484894
#
# Iteration 324. Time: 0:00:04.525811
#
# Iteration 325. Time: 0:00:04.496019
#
# Iteration 326. Time: 0:00:04.535421
#
# Iteration 327. Time: 0:00:04.485653
#
# Iteration 328. Time: 0:00:04.514608
#
# Iteration 329. Time: 0:00:04.496108
#
# Iteration 330. Time: 0:00:04.489255
#
# Iteration 331. Time: 0:00:04.496047
#
# Iteration 332. Time: 0:00:04.495825
#
# Iteration 333. Time: 0:00:04.491771
#
# Iteration 334. Time: 0:00:04.616141
#
# Iteration 335. Time: 0:00:04.525753
#
# Iteration 336. Time: 0:00:04.496580
#
# Iteration 337. Time: 0:00:04.505821
#
# Iteration 338. Time: 0:00:04.503627
#
# Iteration 339. Time: 0:00:04.515354
#
# Iteration 340. Time: 0:00:04.525709
#
# Iteration 341. Time: 0:00:04.495828
#
# Iteration 342. Time: 0:00:04.516380
#
# Iteration 343. Time: 0:00:04.524095
#
# Iteration 344. Time: 0:00:04.500100
#
# Iteration 345. Time: 0:00:04.487172
#
# Iteration 346. Time: 0:00:04.498356
#
# Iteration 347. Time: 0:00:04.513797
#
# Iteration 348. Time: 0:00:04.655867
#
# Iteration 349. Time: 0:00:04.505785
#
# Iteration 350. Time: 0:00:04.491969
#
# Iteration 351. Time: 0:00:04.483918
#
# Iteration 352. Time: 0:00:04.498278
#
# Iteration 353. Time: 0:00:04.466258
#
# Iteration 354. Time: 0:00:04.494230
#
# Iteration 355. Time: 0:00:04.530225
#
# Iteration 356. Time: 0:00:04.475999
#
# Iteration 357. Time: 0:00:04.495697
#
# Iteration 358. Time: 0:00:04.521627
#
# Iteration 359. Time: 0:00:04.521081
#
# Iteration 360. Time: 0:00:04.498097
#
# Iteration 361. Time: 0:00:04.633895
#
# Iteration 362. Time: 0:00:04.505547
#
# Iteration 363. Time: 0:00:04.510063
#
# Iteration 364. Time: 0:00:04.495207
#
# Iteration 365. Time: 0:00:04.486705
#
# Iteration 366. Time: 0:00:04.493216
#
# Iteration 367. Time: 0:00:04.494320
#
# Iteration 368. Time: 0:00:04.518155
#
# Iteration 369. Time: 0:00:04.506536
#
# Iteration 370. Time: 0:00:04.483564
#
# Iteration 371. Time: 0:00:04.527176
#
# Iteration 372. Time: 0:00:04.490180
#
# Iteration 373. Time: 0:00:04.463815
#
# Iteration 374. Time: 0:00:04.762025
#
# Iteration 375. Time: 0:00:04.484796
#
# Iteration 376. Time: 0:00:04.499483
#
# Iteration 377. Time: 0:00:04.487650
#
# Iteration 378. Time: 0:00:04.486694
#
# Iteration 379. Time: 0:00:04.500242
#
# Iteration 380. Time: 0:00:04.477223
#
# Iteration 381. Time: 0:00:04.525476
#
# Iteration 382. Time: 0:00:04.478242
#
# Iteration 383. Time: 0:00:04.484750
#
# Iteration 384. Time: 0:00:04.568298
#
# Iteration 385. Time: 0:00:04.535526
#
# Iteration 386. Time: 0:00:04.527094
#
# Iteration 387. Time: 0:00:04.601315
#
# Iteration 388. Time: 0:00:04.624826
#
# Iteration 389. Time: 0:00:04.468180
#
# Iteration 390. Time: 0:00:04.501106
#
# Iteration 391. Time: 0:00:04.510111
#
# Iteration 392. Time: 0:00:04.494002
#
# Iteration 393. Time: 0:00:04.503486
#
# Iteration 394. Time: 0:00:04.473840
#
# Iteration 395. Time: 0:00:04.586286
#
# Iteration 396. Time: 0:00:04.530354
#
# Iteration 397. Time: 0:00:04.498935
#
# Iteration 398. Time: 0:00:04.740783
#
# Iteration 399. Time: 0:00:04.600832
#
# Iteration 400. Time: 0:00:04.546033
#
# Iteration 401. Time: 0:00:04.630940
#
# Iteration 402. Time: 0:00:04.499238
#
# Iteration 403. Time: 0:00:04.493654
#
# Iteration 404. Time: 0:00:04.503722
#
# Iteration 405. Time: 0:00:04.463236
#
# Iteration 406. Time: 0:00:04.479737
#
# Iteration 407. Time: 0:00:04.508768
#
# Iteration 408. Time: 0:00:04.505043
#
# Iteration 409. Time: 0:00:04.509199
#
# Iteration 410. Time: 0:00:04.540955
#
# Iteration 411. Time: 0:00:04.549559
#
# Iteration 412. Time: 0:00:04.503489
#
# Iteration 413. Time: 0:00:04.490729
#
# Iteration 414. Time: 0:00:04.664039
#
# Iteration 415. Time: 0:00:04.499878
#
# Iteration 416. Time: 0:00:04.493224
#
# Iteration 417. Time: 0:00:04.491169
#
# Iteration 418. Time: 0:00:04.481138
#
# Iteration 419. Time: 0:00:04.485680
#
# Iteration 420. Time: 0:00:04.488615
#
# Iteration 421. Time: 0:00:04.500513
#
# Iteration 422. Time: 0:00:04.506295
#
# Iteration 423. Time: 0:00:04.520253
#
# Iteration 424. Time: 0:00:04.492950
#
# Iteration 425. Time: 0:00:04.486535
#
# Iteration 426. Time: 0:00:04.470164
#
# Iteration 427. Time: 0:00:04.662521
#
# Iteration 428. Time: 0:00:04.520706
#
# Iteration 429. Time: 0:00:04.496604
#
# Iteration 430. Time: 0:00:04.506648
#
# Iteration 431. Time: 0:00:04.507023
#
# Iteration 432. Time: 0:00:04.485257
#
# Iteration 433. Time: 0:00:04.467106
#
# Iteration 434. Time: 0:00:04.512044
#
# Iteration 435. Time: 0:00:04.510751
#
# Iteration 436. Time: 0:00:04.486702
#
# Iteration 437. Time: 0:00:04.539261
#
# Iteration 438. Time: 0:00:04.533551
#
# Iteration 439. Time: 0:00:04.513300
#
# Iteration 440. Time: 0:00:04.634871
#
# Iteration 441. Time: 0:00:04.635358
#
# Iteration 442. Time: 0:00:04.469441
#
# Iteration 443. Time: 0:00:04.496991
#
# Iteration 444. Time: 0:00:04.494005
#
# Iteration 445. Time: 0:00:04.518421
#
# Iteration 446. Time: 0:00:04.478207
# Iteration 447. Time: 0:00:04.496559
#
# Iteration 448. Time: 0:00:04.501238
#
# Iteration 449. Time: 0:00:04.472168
#
# Iteration 450. Time: 0:00:04.494204
#
# Iteration 451. Time: 0:00:04.548294
#
# Iteration 452. Time: 0:00:04.512826
#
# Iteration 453. Time: 0:00:04.490299
#
# Iteration 454. Time: 0:00:04.645942
#
# Iteration 455. Time: 0:00:04.527444
#
# Iteration 456. Time: 0:00:04.494745
#
# Iteration 457. Time: 0:00:04.493722
#
# Iteration 458. Time: 0:00:04.494091
#
# Iteration 459. Time: 0:00:04.478856
#
# Iteration 460. Time: 0:00:04.498930
#
# Iteration 461. Time: 0:00:04.523507
#
# Iteration 462. Time: 0:00:04.499023
#
# Iteration 463. Time: 0:00:04.490122
#
# Iteration 464. Time: 0:00:04.510287
#
# Iteration 465. Time: 0:00:04.532004
#
# Iteration 466. Time: 0:00:04.487203
#
# Iteration 467. Time: 0:00:04.719922
#
# Iteration 468. Time: 0:00:04.504537
#
# Iteration 469. Time: 0:00:04.703335
#
# Iteration 470. Time: 0:00:04.501727
#
# Iteration 471. Time: 0:00:04.507321
#
# Iteration 472. Time: 0:00:04.498844
#
# Iteration 473. Time: 0:00:04.521897
#
# Iteration 474. Time: 0:00:04.497760
#
# Iteration 475. Time: 0:00:04.477458
#
# Iteration 476. Time: 0:00:04.505288
#
# Iteration 477. Time: 0:00:04.479308
#
# Iteration 478. Time: 0:00:04.477351
#
# Iteration 479. Time: 0:00:04.486099
#
# Iteration 480. Time: 0:00:04.699498
#
# Iteration 481. Time: 0:00:04.554954
#
# Iteration 482. Time: 0:00:04.500988
#
# Iteration 483. Time: 0:00:04.498085
#
# Iteration 484. Time: 0:00:04.508847
#
# Iteration 485. Time: 0:00:04.506839
#
# Iteration 486. Time: 0:00:04.481389
#
# Iteration 487. Time: 0:00:04.521634
#
# Iteration 488. Time: 0:00:04.486876
#
# Iteration 489. Time: 0:00:04.504656
#
# Iteration 490. Time: 0:00:04.511687
#
# Iteration 491. Time: 0:00:04.519516
#
# Iteration 492. Time: 0:00:04.530076
#
# Iteration 493. Time: 0:00:04.519687
#
# Iteration 494. Time: 0:00:04.658632
#
# Iteration 495. Time: 0:00:04.499863
#
# Iteration 496. Time: 0:00:04.517932
#
# Iteration 497. Time: 0:00:04.510033
#
# Iteration 498. Time: 0:00:04.483912
#
# Iteration 499. Time: 0:00:04.507148
#
# Iteration 500. Time: 0:00:04.519171
#
# Iteration 501. Time: 0:00:04.524058
#
# Iteration 502. Time: 0:00:04.505351
#
# Iteration 503. Time: 0:00:04.503430
#
# Iteration 504. Time: 0:00:04.502960
#
# Iteration 505. Time: 0:00:04.531883
#
# Iteration 506. Time: 0:00:04.834704
#
# Iteration 507. Time: 0:00:05.918604
#
# Iteration 508. Time: 0:00:05.421336
#
# Iteration 509. Time: 0:00:04.590318
#
# Iteration 510. Time: 0:00:04.481814
#
# Iteration 511. Time: 0:00:04.561643
#
# Iteration 512. Time: 0:00:04.497524
#
# Iteration 513. Time: 0:00:04.667210
#
# Iteration 514. Time: 0:00:04.484289
#
# Iteration 515. Time: 0:00:04.469733
#
# Iteration 516. Time: 0:00:04.489735
#
# Iteration 517. Time: 0:00:04.521434
#
# Iteration 518. Time: 0:00:04.470406
#
# Iteration 519. Time: 0:00:04.508286
#
# Iteration 520. Time: 0:00:04.622838
#
# Iteration 521. Time: 0:00:04.469165
#
# Iteration 522. Time: 0:00:04.472841
#
# Iteration 523. Time: 0:00:04.484334
#
# Iteration 524. Time: 0:00:04.474060
#
# Iteration 525. Time: 0:00:04.466314
#
# Iteration 526. Time: 0:00:04.490299
#
# Iteration 527. Time: 0:00:05.461281
#
# Iteration 528. Time: 0:00:04.489138
#
# Iteration 529. Time: 0:00:04.463946
#
# Iteration 530. Time: 0:00:05.415864
#
# Iteration 531. Time: 0:00:05.081132
#
# Iteration 532. Time: 0:00:04.705984
#
# Iteration 533. Time: 0:00:04.619405
#
# Iteration 534. Time: 0:00:04.469828
#
# Iteration 535. Time: 0:00:04.477411
#
# Iteration 536. Time: 0:00:04.494367
#
# Iteration 537. Time: 0:00:04.483319
#
# Iteration 538. Time: 0:00:04.503296
#
# Iteration 539. Time: 0:00:04.468980
#
# Iteration 540. Time: 0:00:04.553891
#
# Iteration 541. Time: 0:00:04.489052
#
# Iteration 542. Time: 0:00:04.485461
#
# Iteration 543. Time: 0:00:04.526744
#
# Iteration 544. Time: 0:00:04.507913
#
# Iteration 545. Time: 0:00:04.473371
#
# Iteration 546. Time: 0:00:04.610539
#
# Iteration 547. Time: 0:00:04.476911
#
# Iteration 548. Time: 0:00:04.497071
#
# Iteration 549. Time: 0:00:04.478608
#
# Iteration 550. Time: 0:00:04.455099
#
# Iteration 551. Time: 0:00:04.464782
#
# Iteration 552. Time: 0:00:04.483587
#
# Iteration 553. Time: 0:00:04.483510
#
# Iteration 554. Time: 0:00:04.488847
#
# Iteration 555. Time: 0:00:04.476887
#
# Iteration 556. Time: 0:00:04.498033
#
# Iteration 557. Time: 0:00:04.474694
#
# Iteration 558. Time: 0:00:04.504234
#
# Iteration 559. Time: 0:00:04.598788
#
# Iteration 560. Time: 0:00:04.470985
#
# Iteration 561. Time: 0:00:04.534057
#
# Iteration 562. Time: 0:00:04.503443
#
# Iteration 563. Time: 0:00:04.511714
#
# Iteration 564. Time: 0:00:04.474611
#
# Iteration 565. Time: 0:00:04.464852
#
# Iteration 566. Time: 0:00:04.509447
#
# Iteration 567. Time: 0:00:04.520041
#
# Iteration 568. Time: 0:00:04.489965
#
# Iteration 569. Time: 0:00:04.482704
#
# Iteration 570. Time: 0:00:04.505339
#
# Iteration 571. Time: 0:00:04.477646
#
# Iteration 572. Time: 0:00:04.660985
#
# Iteration 573. Time: 0:00:04.499221
#
# Iteration 574. Time: 0:00:04.459642
#
# Iteration 575. Time: 0:00:04.486229
#
# Iteration 576. Time: 0:00:04.479783
#
# Iteration 577. Time: 0:00:04.489685
#
# Iteration 578. Time: 0:00:04.453763
#
# Iteration 579. Time: 0:00:04.504706
#
# Iteration 580. Time: 0:00:04.465650
#
# Iteration 581. Time: 0:00:04.472933
#
# Iteration 582. Time: 0:00:04.482245
#
# Iteration 583. Time: 0:00:04.466831
#
# Iteration 584. Time: 0:00:04.454233
#
# Iteration 585. Time: 0:00:04.589905
#
# Iteration 586. Time: 0:00:04.622781
#
# Iteration 587. Time: 0:00:04.457050
#
# Iteration 588. Time: 0:00:04.465797
#
# Iteration 589. Time: 0:00:04.486438
#
# Iteration 590. Time: 0:00:04.455162
#
# Iteration 591. Time: 0:00:04.490072
#
# Iteration 592. Time: 0:00:04.471790
#
# Iteration 593. Time: 0:00:06.066096
#
# Iteration 594. Time: 0:00:04.484130
#
# Iteration 595. Time: 0:00:04.590865
#
# Iteration 596. Time: 0:00:04.684827
#
# Iteration 597. Time: 0:00:04.483719
#
# Iteration 598. Time: 0:00:04.500091
#
# Iteration 599. Time: 0:00:04.612526
#
# 0:55:59.221107

# %%
print(max(mean))
print(min(mean))
# Out:
# 1.80247038102
# -2.31798419313

# %%
print(mean)
# Out:
# [ 1.28247188  0.63748917  1.80247038  1.02918157  0.82248318 -0.71480715
#   0.29587115  0.14857127  1.43956019  0.33251357  0.34735089  1.65440324
#  -0.57412651  1.74553235  1.26245191 -1.39858631  0.5601826  -0.99654739
#   0.7020176   0.8846054   0.24879804  0.86815845  0.06132029 -1.13023133
#  -1.43556112  0.25183769 -1.91157598  0.76030668  0.28293769  1.13939494
#   0.31108729 -0.51236596  0.48555772 -2.06741238  0.58440537 -0.07790519
#   1.35153606  0.87616974  1.55309921  0.03226904  0.16199132  0.59017867
#  -0.85261749 -0.1526775   0.28320064  0.4217614  -0.95205898 -0.80692458
#   0.4578584  -0.40566918  1.51877578  0.56687946  1.42510046 -0.59580839
#  -0.4750243  -1.36430736  1.26249885  0.72349948 -0.95632585  0.42967481
#  -1.07403307  1.43038483 -1.56994222 -0.49869158 -0.24300631  0.68196646
#   0.86248651 -0.77804233 -1.3487668   0.64610209 -0.65888903 -0.7419359
#   0.49722286 -0.59613539 -1.05151505  0.35836648  0.56173366 -2.31798419
#   1.02286052 -0.33457472 -0.36459745 -0.57716738  0.73148969 -0.39695548
#   0.63957792  0.23485221  0.37678661 -0.17336626 -1.10152597 -0.555681
#  -0.18036243  0.6177786  -1.43336792 -1.0448517  -1.36882158 -0.11526365
#  -1.06503553  1.08389113  0.18941813  0.29281179  0.6042534  -0.81795246
#   1.13713298  0.51861666  0.66718454]
